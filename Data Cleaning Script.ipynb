# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ## Loading the dataset

# %% [markdown]
# First things first, we will import the required libraries

# %%
# import pandas
import pandas as pd

# %% [markdown]
# Now, we will load the quakes dataset into the notebook

# %%
# load the dataset
df= pd.read_csv('quakes.csv')

# %% [markdown]
# Let us see the first few rows in the dataset

# %%
df.head()
# Out:
#                        time   latitude   longitude      depth   mag magType  \
# 0  2023-11-15T09:05:07.304Z  61.580800 -149.847000  32.800000  1.70      ml
# 1  2023-11-15T08:53:06.688Z  61.079400 -147.883000  14.800000  1.00      ml
# 2  2023-11-15T08:41:52.480Z  19.380667 -155.285339   0.320000  1.73      md
# 3  2023-11-15T07:44:53.035Z  61.638200 -149.782800  32.900000  1.90      ml
# 4  2023-11-15T07:19:44.540Z  18.972166 -155.451660  34.759998  1.87      md
#
#     nst    gap  dmin   rms  ...                   updated  \
# 0   NaN    NaN   NaN  0.22  ...  2023-11-15T09:06:28.283Z
# 1   NaN    NaN   NaN  0.80  ...  2023-11-15T08:54:38.102Z
# 2  15.0  153.0   NaN  0.20  ...  2023-11-15T08:56:22.252Z
# 3   NaN    NaN   NaN  0.31  ...  2023-11-15T07:46:10.981Z
# 4  37.0  236.0   NaN  0.12  ...  2023-11-15T07:22:58.830Z
#
#                           place        type horizontalError depthError  \
# 0   5 km SSW of Houston, Alaska  earthquake             NaN       0.20
# 1  55 km NE of Whittier, Alaska  earthquake             NaN       0.30
# 2    8 km SW of Volcano, Hawaii  earthquake            0.33       0.38
# 3                           NaN  earthquake             NaN       0.20
# 4   17 km SE of Naalehu, Hawaii  earthquake            0.71       0.89
#
#    magError  magNst     status  locationSource magSource
# 0       NaN     NaN  automatic              ak        ak
# 1       NaN     NaN  automatic              ak        ak
# 2      0.59    15.0  automatic              hv        hv
# 3       NaN     NaN  automatic              ak        ak
# 4      0.88     5.0  automatic              hv        hv
#
# [5 rows x 22 columns]

# %% [markdown]
# Now, we will access the shape of the dataset

# %%
# check the shape of the dataset
df.shape
# Out:
# (19244, 22)

# %% [markdown]
# **We have 19,244 rows and 22 columns in the dataset**

# %% [markdown]
# Let's examine the data types of the columns in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19244 entries, 0 to 19243
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             19244 non-null  object
#  1   latitude         19244 non-null  float64
#  2   longitude        19244 non-null  float64
#  3   depth            19244 non-null  float64
#  4   mag              19244 non-null  float64
#  5   magType          19244 non-null  object
#  6   nst              12628 non-null  float64
#  7   gap              12626 non-null  float64
#  8   dmin             10842 non-null  float64
#  9   rms              19243 non-null  float64
#  10  net              19244 non-null  object
#  11  id               19244 non-null  object
#  12  updated          19244 non-null  object
#  13  place            18272 non-null  object
#  14  type             19244 non-null  object
#  15  horizontalError  11691 non-null  float64
#  16  depthError       19243 non-null  float64
#  17  magError         12556 non-null  float64
#  18  magNst           12585 non-null  float64
#  19  status           19244 non-null  object
#  20  locationSource   19244 non-null  object
#  21  magSource        19244 non-null  object
# dtypes: float64(12), object(10)
# memory usage: 3.2+ MB

# %% [markdown]
# It is evident that the dataset contains null values, and the data types of some columns are not appropriate.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Step 1: Converting the 'Time' and 'Updated' Column to Datetime

# %% [markdown]
# In the initial data cleaning step, we will convert the "time" and "updated" column to a datetime data type.

# %%
# Convert the 'time' and 'updated' column to datetime
df['time'] = pd.to_datetime(df['time'])
df['updated'] = pd.to_datetime(df['updated'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19244 entries, 0 to 19243
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             19244 non-null  datetime64[ns, UTC]
#  1   latitude         19244 non-null  float64
#  2   longitude        19244 non-null  float64
#  3   depth            19244 non-null  float64
#  4   mag              19244 non-null  float64
#  5   magType          19244 non-null  object
#  6   nst              12628 non-null  float64
#  7   gap              12626 non-null  float64
#  8   dmin             10842 non-null  float64
#  9   rms              19243 non-null  float64
#  10  net              19244 non-null  object
#  11  id               19244 non-null  object
#  12  updated          19244 non-null  datetime64[ns, UTC]
#  13  place            18272 non-null  object
#  14  type             19244 non-null  object
#  15  horizontalError  11691 non-null  float64
#  16  depthError       19243 non-null  float64
#  17  magError         12556 non-null  float64
#  18  magNst           12585 non-null  float64
#  19  status           19244 non-null  object
#  20  locationSource   19244 non-null  object
#  21  magSource        19244 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(12), object(8)
# memory usage: 3.2+ MB

# %% [markdown]
# **We have converted 'time' and 'updated' columns from the object data type to datetime64[ns, UTC]. The data now reflects a more appropriate datetime format for further analysis and processing.**

# %% [markdown]
# ### Step 2: Setting Time Column as Index

# %% [markdown]
# In the second data cleaning step, we will set the time column as the new index for the dataset.

# %%
# set time colum as index
df.index = df.time

# %%
df.head()
# Out:
#                                                              time   latitude  \
# time
# 2023-11-15 09:05:07.304000+00:00 2023-11-15 09:05:07.304000+00:00  61.580800
# 2023-11-15 08:53:06.688000+00:00 2023-11-15 08:53:06.688000+00:00  61.079400
# 2023-11-15 08:41:52.480000+00:00 2023-11-15 08:41:52.480000+00:00  19.380667
# 2023-11-15 07:44:53.035000+00:00 2023-11-15 07:44:53.035000+00:00  61.638200
# 2023-11-15 07:19:44.540000+00:00 2023-11-15 07:19:44.540000+00:00  18.972166
#
#                                    longitude      depth   mag magType   nst  \
# time
# 2023-11-15 09:05:07.304000+00:00 -149.847000  32.800000  1.70      ml   NaN
# 2023-11-15 08:53:06.688000+00:00 -147.883000  14.800000  1.00      ml   NaN
# 2023-11-15 08:41:52.480000+00:00 -155.285339   0.320000  1.73      md  15.0
# 2023-11-15 07:44:53.035000+00:00 -149.782800  32.900000  1.90      ml   NaN
# 2023-11-15 07:19:44.540000+00:00 -155.451660  34.759998  1.87      md  37.0
#
#                                     gap  dmin   rms  ...  \
# time                                                 ...
# 2023-11-15 09:05:07.304000+00:00    NaN   NaN  0.22  ...
# 2023-11-15 08:53:06.688000+00:00    NaN   NaN  0.80  ...
# 2023-11-15 08:41:52.480000+00:00  153.0   NaN  0.20  ...
# 2023-11-15 07:44:53.035000+00:00    NaN   NaN  0.31  ...
# 2023-11-15 08:53:06.688000+00:00    NaN   NaN  0.80  ...
# 2023-11-15 08:41:52.480000+00:00  153.0   NaN  0.20  ...
# 2023-11-15 07:44:53.035000+00:00    NaN   NaN  0.31  ...
# 2023-11-15 07:19:44.540000+00:00  236.0   NaN  0.12  ...
#
#                                                           updated  \
# time
# 2023-11-15 09:05:07.304000+00:00 2023-11-15 09:06:28.283000+00:00
# 2023-11-15 08:53:06.688000+00:00 2023-11-15 08:54:38.102000+00:00
# 2023-11-15 08:41:52.480000+00:00 2023-11-15 08:56:22.252000+00:00
# 2023-11-15 07:44:53.035000+00:00 2023-11-15 07:46:10.981000+00:00
# 2023-11-15 07:19:44.540000+00:00 2023-11-15 07:22:58.830000+00:00
#
#                                                          place        type  \
# time
# 2023-11-15 09:05:07.304000+00:00   5 km SSW of Houston, Alaska  earthquake
# 2023-11-15 08:53:06.688000+00:00  55 km NE of Whittier, Alaska  earthquake
# 2023-11-15 08:41:52.480000+00:00    8 km SW of Volcano, Hawaii  earthquake
# 2023-11-15 07:44:53.035000+00:00                           NaN  earthquake
# 2023-11-15 07:19:44.540000+00:00   17 km SE of Naalehu, Hawaii  earthquake
#
#                                  horizontalError depthError  magError  magNst  \
# time
# 2023-11-15 09:05:07.304000+00:00             NaN       0.20       NaN     NaN
# 2023-11-15 08:53:06.688000+00:00             NaN       0.30       NaN     NaN
# 2023-11-15 08:41:52.480000+00:00            0.33       0.38      0.59    15.0
# 2023-11-15 07:44:53.035000+00:00             NaN       0.20       NaN     NaN
# 2023-11-15 07:19:44.540000+00:00            0.71       0.89      0.88     5.0
#
#                                      status  locationSource magSource
# time
# 2023-11-15 09:05:07.304000+00:00  automatic              ak        ak
# 2023-11-15 08:53:06.688000+00:00  automatic              ak        ak
# 2023-11-15 08:41:52.480000+00:00  automatic              hv        hv
# 2023-11-15 07:44:53.035000+00:00  automatic              ak        ak
# 2023-11-15 07:19:44.540000+00:00  automatic              hv        hv
#
# [5 rows x 22 columns]

# %% [markdown]
# Great!!!

# %% [markdown]
# ### Step 3: Handling Null Values

# %% [markdown]
# In this stage of data cleaning, we will address and handle all null values present in the dataset.

# %% [markdown]
# Let's identify which datasets within the dataset contain null values.

# %%
# checking for nulls
df.isnull().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   0
# magType               0
# nst                6616
# gap                6618
# dmin               8402
# rms                   1
# net                   0
# id                    0
# updated               0
# place               972
# type                  0
# horizontalError    7553
# depthError            1
# magError           6688
# magNst             6659
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %% [markdown]
# 9 columns contain null values in the dataset

# %% [raw]
# df[['nst', 'gap', 'dmin', 'rms', 'place', 'horizontalError', 'depthError', 'magError', 'magNst']]

# %% [markdown]
# ### a. Dealing with nulls in the 'place' column

# %% [markdown]
# For null values in the "place" column, we will substitute them with 'Others' to denote alternative locations.

# %%
df['place'] = df['place'].fillna('Others')

# %%
# checking for nulls
df.isnull().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   0
# magType               0
# nst                6616
# gap                6618
# dmin               8402
# rms                   1
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    7553
# depthError            1
# magError           6688
# magNst             6659
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %% [markdown]
# Good!!!

# %% [markdown]
# ### b. Dealing with nulls in the other columns

# %% [markdown]
# Now, we will deal with the nulls in other columns. Since the remaining columns are all quantitative variable, we will fill all the nulls with zero.

# %%
# List of columns to fill null values
columns_to_fill = ['nst', 'gap', 'dmin', 'horizontalError', 'depthError', 'magError', 'magNst', 'rms']

# Iterate through each column and fill null values with 0
for column in columns_to_fill:
    # Fill null values in the specified column with 0
    df[column] = df[column].fillna(0)

# %%
# checking for nulls
df.isnull().sum()
# Out:
# time               0
# latitude           0
# longitude          0
# depth              0
# mag                0
# magType            0
# nst                0
# gap                0
# dmin               0
# rms                0
# net                0
# id                 0
# updated            0
# place              0
# type               0
# horizontalError    0
# depthError         0
# magError           0
# magNst             0
# status             0
# locationSource     0
# magSource          0
# dtype: int64

# %% [markdown]
# **Excellent! We have effectively addressed all null values.**

# %% [markdown]
# ### Step 4: Converting columns to appropriate data types

# %% [markdown]
# Now, we will attempt to convert the various columns into the appropriate data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19244 entries, 2023-11-15 09:05:07.304000+00:00 to 2023-09-01 00:04:57.310000+00:00
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             19244 non-null  datetime64[ns, UTC]
#  1   latitude         19244 non-null  float64
#  2   longitude        19244 non-null  float64
#  3   depth            19244 non-null  float64
#  4   mag              19244 non-null  float64
#  5   magType          19244 non-null  object
#  6   nst              19244 non-null  float64
#  7   gap              19244 non-null  float64
#  8   dmin             19244 non-null  float64
#  9   rms              19244 non-null  float64
#  10  net              19244 non-null  object
#  11  id               19244 non-null  object
#  12  updated          19244 non-null  datetime64[ns, UTC]
#  13  place            19244 non-null  object
#  14  type             19244 non-null  object
#  15  horizontalError  19244 non-null  float64
#  16  depthError       19244 non-null  float64
#  17  magError         19244 non-null  float64
#  18  magNst           19244 non-null  float64
#  19  status           19244 non-null  object
#  20  locationSource   19244 non-null  object
#  21  magSource        19244 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(12), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# We will convert the 'magType', 'net', 'id', 'place', 'type', 'status', 'locationSource', 'magSource', and 'state' column from object to string data type

# %%
# List of columns to convert to string data type
columns_to_convert_to_string = ['magType', 'net', 'id', 'place', 'type', 'status', 'locationSource', 'magSource']

# Convert specified columns to string data type
df[columns_to_convert_to_string] = df[columns_to_convert_to_string].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19244 entries, 2023-11-15 09:05:07.304000+00:00 to 2023-09-01 00:04:57.310000+00:00
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             19244 non-null  datetime64[ns, UTC]
#  1   latitude         19244 non-null  float64
#  2   longitude        19244 non-null  float64
#  3   depth            19244 non-null  float64
#  4   mag              19244 non-null  float64
#  5   magType          19244 non-null  string
#  6   nst              19244 non-null  float64
#  7   gap              19244 non-null  float64
#  8   dmin             19244 non-null  float64
#  9   rms              19244 non-null  float64
#  10  net              19244 non-null  string
#  11  id               19244 non-null  string
#  12  updated          19244 non-null  datetime64[ns, UTC]
#  13  place            19244 non-null  string
#  14  type             19244 non-null  string
#  15  horizontalError  19244 non-null  float64
#  16  depthError       19244 non-null  float64
#  17  magError         19244 non-null  float64
#  18  magNst           19244 non-null  float64
#  19  status           19244 non-null  string
#  20  locationSource   19244 non-null  string
#  21  magSource        19244 non-null  string
# dtypes: datetime64[ns, UTC](2), float64(12), string(8)
# memory usage: 3.4 MB

# %% [markdown]
# Next we will convert the 'nst' and 'magNst'column into integers

# %%
# List of columns to convert to integer data type
columns_to_convert_to_int = ['nst', 'magNst']

# Convert specified columns to integer data type
df[columns_to_convert_to_int] = df[columns_to_convert_to_int].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19244 entries, 2023-11-15 09:05:07.304000+00:00 to 2023-09-01 00:04:57.310000+00:00
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             19244 non-null  datetime64[ns, UTC]
#  1   latitude         19244 non-null  float64
#  2   longitude        19244 non-null  float64
#  3   depth            19244 non-null  float64
#  4   mag              19244 non-null  float64
#  5   magType          19244 non-null  string
#  6   nst              19244 non-null  int32
#  7   gap              19244 non-null  float64
#  8   dmin             19244 non-null  float64
#  9   rms              19244 non-null  float64
#  10  net              19244 non-null  string
#  11  id               19244 non-null  string
#  12  updated          19244 non-null  datetime64[ns, UTC]
#  13  place            19244 non-null  string
#  14  type             19244 non-null  string
#  15  horizontalError  19244 non-null  float64
#  16  depthError       19244 non-null  float64
#  17  magError         19244 non-null  float64
#  18  magNst           19244 non-null  int32
#  19  status           19244 non-null  string
#  20  locationSource   19244 non-null  string
#  21  magSource        19244 non-null  string
# dtypes: datetime64[ns, UTC](2), float64(10), int32(2), string(8)
# memory usage: 3.2 MB

# %% [markdown]
# **Great. We have successfully converted all columns to their appropriate data types.**

# %%
list(df.type.unique())
# Out:
# ['earthquake',
#  'quarry blast',
#  'explosion',
#  'other event',
#  'ice quake',
#  'experimental explosion',
#  'landslide',
#  'volcanic eruption',
#  'mining explosion']

# %% [markdown]
# ### Step 5: Obtaining the state and country of the seismic events

# %% [markdown]
# We will enhance our dataset by extracting precise state and country information from the 'longitude' and 'latitude column using the Geopy Python library. This library utilizes longitude and latitude coordinates to generate the corresponding state and country names. Consequently, we will create a new column named 'state_country' to capture this geographically derived information.

# %%
df.head(1)
# Out:
#                                                              time  latitude  \
# time
# 2023-11-15 09:05:07.304000+00:00 2023-11-15 09:05:07.304000+00:00   61.5808
#
#                                   longitude  depth  mag magType  nst  gap  \
# time
# 2023-11-15 09:05:07.304000+00:00   -149.847   32.8  1.7      ml    0  0.0
#
#                                   dmin   rms  ...  \
# time                                          ...
# 2023-11-15 09:05:07.304000+00:00   0.0  0.22  ...
#
#                                                           updated  \
# time
# 2023-11-15 09:05:07.304000+00:00 2023-11-15 09:06:28.283000+00:00
#
#                                                         place        type  \
# time
# 2023-11-15 09:05:07.304000+00:00  5 km SSW of Houston, Alaska  earthquake
#
#                                  horizontalError depthError  magError  magNst  \
# time
# 2023-11-15 09:05:07.304000+00:00             0.0        0.2       0.0       0
#
#                                      status  locationSource magSource
# time
# 2023-11-15 09:05:07.304000+00:00  automatic              ak        ak
#
# [1 rows x 22 columns]

# %% [markdown]
# As an example, we will use the library to obtain the exact state and location of the first seismic event in the datatset

# %%
# import the required library
from geopy.geocoders import Nominatim

# Create a Nominatim geolocator
geolocator = Nominatim(user_agent="reverse_geocoding_example")

# coordinates of the first seismic event
latitude = 61.5808
longitude = -149.847

# Perform reverse geocoding
location = geolocator.reverse((latitude, longitude), language='en')

if location is not None:
    address = location.address
    print(f"The location at ({latitude}, {longitude}) is: {address}")
else:
    print(f"No location found for coordinates ({latitude}, {longitude})")
# Out:
# The location at (61.5808, -149.847) is: Beavertail Drive, Matanuska-Susitna, Alaska, United States

# %% [markdown]
# **This shows the exact location of the first seismic event**

# %% [markdown]
# We will now replicate the process to extract the state and country information for all seismic events. To mitigate runtime errors, we will parse in the coordinates of 50 events at a time.

# %% [markdown]
# **Desclaimer: This body of code might take about 90 minutes to run, due to numerous request sent to Geopy**

# %%
# import tqdm to show the progress bar
from tqdm import tqdm  

# Create a Nominatim geolocator
geolocator = Nominatim(user_agent="reverse_geocoding_examples")


# Function to perform reverse geocoding for a batch of rows
def reverse_geocode_batch(batch):
    results = []
    for index, row in batch.iterrows():
        location = geolocator.reverse((row['latitude'], row['longitude']), language='en')
        if location is not None:
            results.append(location.address)
        else:
            results.append("No location found")
    return results

# make a copy of the dataset
df_reset = df

# Reset the index before processing in batches
df_reset = df.reset_index(drop=True)

# Process the DataFrame in batches of 50 rows
batch_size = 50
num_batches = len(df_reset) // batch_size + 1

 
# Enable progress bar for pandas
tqdm.pandas()

# Apply the function to create a new column 'state_country'
df_reset['state_country'] = df_reset.groupby(df_reset.index // batch_size).progress_apply(reverse_geocode_batch).explode().reset_index(drop=True)

# Print the updated DataFrame
df_reset
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 385/385 [2:40:27<00:00, 25.01s/it]
#                                   time   latitude   longitude      depth  \
# 0     2023-11-15 09:05:07.304000+00:00  61.580800 -149.847000  32.800000
# 1     2023-11-15 08:53:06.688000+00:00  61.079400 -147.883000  14.800000
# 2     2023-11-15 08:41:52.480000+00:00  19.380667 -155.285339   0.320000
# 3     2023-11-15 07:44:53.035000+00:00  61.638200 -149.782800  32.900000
# 4     2023-11-15 07:19:44.540000+00:00  18.972166 -155.451660  34.759998
# ...                                ...        ...         ...        ...
# 19239 2023-09-01 01:10:27.784000+00:00  53.154800 -164.532800  35.000000
# 19240 2023-09-01 00:55:24.900000+00:00  19.210167 -155.348007  28.299999
# 19241 2023-09-01 00:45:43.100000+00:00  17.937167  -66.917667  13.160000
# 19242 2023-09-01 00:42:08.428000+00:00  60.279600 -147.859600   5.600000
# 19243 2023-09-01 00:04:57.310000+00:00  19.132000 -155.375336  29.879999
#
#         mag magType  nst    gap    dmin   rms  ...  \
# 0      1.70      ml    0    0.0  0.0000  0.22  ...
# 1      1.00      ml    0    0.0  0.0000  0.80  ...
# 2      1.73      md   15  153.0  0.0000  0.20  ...
# 3      1.90      ml    0    0.0  0.0000  0.31  ...
# 4      1.87      md   37  236.0  0.0000  0.12  ...
# ...     ...     ...  ...    ...     ...   ...  ...
# 19239  3.00      ml   14  222.0  1.2290  0.33  ...
# 19240  1.71      md   21  189.0  0.0000  0.10  ...
# 19241  2.28      md    6  216.0  0.0525  0.08  ...
# 19242  2.00      ml    0    0.0  0.0000  0.74  ...
# 19243  2.01      md   36  192.0  0.0000  0.09  ...
#
#                               place        type horizontalError depthError  \
# 0       5 km SSW of Houston, Alaska  earthquake            0.00       0.20
# 1      55 km NE of Whittier, Alaska  earthquake            0.00       0.30
# 2        8 km SW of Volcano, Hawaii  earthquake            0.33       0.38
# 3                            Others  earthquake            0.00       0.20
# 4       17 km SE of Naalehu, Hawaii  earthquake            0.71       0.89
# ...                             ...         ...             ...        ...
# 19239   136 km SE of Akutan, Alaska  earthquake            3.27       2.02
# 19240     13 km E of Pāhala, Hawaii  earthquake            0.82       0.63
# 19241            Puerto Rico region  earthquake            0.90       0.41
# 19242  25 km NNE of Chenega, Alaska  earthquake            0.00       0.40
# 19243    13 km SE of Pāhala, Hawaii  earthquake            0.66       0.86
#
#        magError  magNst     status  locationSource  magSource  \
# 0      0.000000       0  automatic              ak         ak
# 1      0.000000       0  automatic              ak         ak
# 2      0.590000      15  automatic              hv         hv
# 3      0.000000       0  automatic              ak         ak
# 4      0.880000       5  automatic              hv         hv
# ...         ...     ...        ...             ...        ...
# 19239  0.128000       8   reviewed              us         us
# 19240  1.730000       4  automatic              hv         hv
# 19241  0.130183       6   reviewed              pr         pr
# 19242  0.000000       0   reviewed              ak         ak
# 19243  1.480000      18  automatic              hv         hv
#
#                                            state_country
# 0      Beavertail Drive, Matanuska-Susitna, Alaska, U...
# 1                         Chugach, Alaska, United States
# 2      Volcano, Volcano CDP, Hawaiʻi County, Hawaii, ...
# 3      Houston, Matanuska-Susitna, Alaska, 99694, Uni...
# 4                                          United States
# ...                                                  ...
# 19239                                  No location found
# 19240  Naliʻikakani Point, Hawaiʻi County, Hawaii, Un...
# 19241  Montalva, Guánica, Puerto Rico, 00647, United ...
# 19242         Unorganized Borough, Alaska, United States
# 19243                                      United States
#
# [19244 rows x 23 columns]

# %%
# set time column as index
df_reset.index = df_reset.time

# %%
df_reset.head()
# Out:
#                                                              time   latitude  \
# time
# 2023-11-15 09:05:07.304000+00:00 2023-11-15 09:05:07.304000+00:00  61.580800
# 2023-11-15 08:53:06.688000+00:00 2023-11-15 08:53:06.688000+00:00  61.079400
# 2023-11-15 08:41:52.480000+00:00 2023-11-15 08:41:52.480000+00:00  19.380667
